# %% [markdown]
# Viết chương trình in ra các ngày trong một tuần bằng tiếng Anh. Mỗi ngày in trên một dòng
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
print('monday\ntuesday')
# Out:
# monday
# tuesday

# %% [markdown]
# tim chu so hang don vi hang nghi cua so nguyen nhap vao tu ban phim

# %%
n = int(input())
don_vi = n%10
hang_nghin = (n//1000)%10
print(don_vi)
print("hang nghin la:", hang_nghin)
# Out:
# 7
# hang nghin la: 4

# %% [markdown]
# and (&) and bit (1 $ 1 =1,con lai bang1)
# or (|): or bit (0 | 0=0,con  lai bang 1)
# xor (^) : xor bit (khac nhau thi bang 1,giong nhau bang 0)
# not(!) = lat bit (1=>0,0=>1)

# %%
n = int(input())
print(bin(n))
# Out:
# 0b101

# %% [markdown]
# hoan doi 2 so khong su dung bien tam thoi su dung phep toan XOR bitwise de hoan doi gia tri cua nhau

# %%
a, b= map(int, input().split())
a, b = b, a
print(a ,b )
# Out:
# 1 2

# %% [markdown]
# Kiểm tra xem một số có phải là lũy thừa của 2 hay không
# Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2 hay không.
# Gợi ý: Đối với lũy thừa của 2, n & (n-1) == 0

# %%
n = int(input())
if n>0 and (n and (n-1) ==0):
    # print (f'{n}la luy thua cua 2')
    print(True)
else:
    # print (f'{n} khong la luy thua cua2')
    print(False)
# Out:
# True

# %%
a = 3
b = 7
print (a =)= b
# Out:
# False

# %% [markdown]
# viêt chương trình chia một số m cho n, kết quả thu được làm tròn xuống

# %%
n = float(input())
k = int(input())
c = n*10*(k+1)
a = c % 10
if a > 5 :
    c = c//10 +1 
else:
    c = c//10
print(c/10**(k))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 n = float(input())
# ----> 2 k = int(input())
#       3 c = n*10*(k+1)
#       4 a = c % 10
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a = float(input())
T = a
print (f'{T:.2f}')
# Out:
# 6.00

# %% [markdown]
# Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số.

# %%
n, m, p, k= map(int, input().split())
if m>n:
    n=m
if k>n:
    n=k 
if p>n:
    n=p
print(n)
# Out:
# 4

# %%
m, n= map(int, input().split())
T = m//n
print(T)
# Out:
# 0

# %%
m, n= map(int, input().split())
T = m//n
a = m % n
if a==0:
    T = T
else:
    T=T+1
print(T)
# Out:
# 52

# %%
a = int(input())
T = a%2
if T==0:
    print(f"even")
else:
    print(f"Odd")
# Out:
# even

# %% [markdown]
# Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No".

# %%
a, b = map(int, input().split())
if a & b <0:
    print('yes')
else:
    print("No")
# Out:
# yes

# %% [markdown]
# Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False"

# %%
a, b = input().split()
if len(a)>len(b):
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# Nhập vào 3 số nguyên dương a, b, c. Kiểm tra xem a, b, c có cấu thành độ dài cạnh của 1 tam giác được không.
# Nếu a, b, c cấu tạo thành được một tam giác, in ra "Yes". Ngược lại in ra "No".

# %%
a, b, c = map(int, input().split())
if a+b>c and a+c>b and c+b>a:
    print(f"yes")
else:
    print(f"No")
# Out:
# yes

# %% [markdown]
# Nhập vào 3 số nguyên dương a,b,c là độ dài 3 cạnh của một tam giác. Kiểm tra 3 số đã nhập có tạo thành một tam giác hợp
# lệ hay không. Nếu không in ra "Không phải tam giác". Nếu có, phân loại tam giác đó là "Tam giác đều", "Tam giác cân", hay
# "Tam giác thường".

# %%
a, b, c = map(int, input().split())
if a+b>c and a+c>b and c+b>a:
    if a == b ==c:
        print("tam giac deu")
    elif a==b or b==c or c==a:
        print("tam giac can")
    elif a != b !=c:
        print("tam giac thuong")
else:
    print("khong phai tam giac")
# Out:
# tam giac thuong

# %% [markdown]
# Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là năm nhuận hay không. Năm nhuận là năm
# chia hết cho 4 nhưng không chia hết cho 100, hoặc chia hết cho 400. Nếu là năm nhuận in ra "Yes", nếu không in ra "No"

# %%
n = int(input())
T = n%4
H = n%100
if T == 0 and H != 0 or n%400 == 0:
    print("yes")
else:
    print("no")
# Out:
# yes

# %% [markdown]
# [Tính tiền điện]
# Nhập vào số kWh điện tiêu thụ. Tính tiền điện theo các bậc sau:
# - 0-50 kWh: 1500đ/kWh
# - 51-100 kWh: 2000đ/kWh
# - 100 kWh: 3000đ/kW

# %%
n = int(input())
if 0<n<50:
    T = n*1500
    print(T)
elif 51<n<100:
    T = 50*1500+(n-50)*2000
    print(T)
else:
    T = (n-100)*3000+50*1500+50*2000
    print(T)
# Out:
# 175000
